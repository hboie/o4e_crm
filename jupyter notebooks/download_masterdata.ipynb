# %% [markdown]
# ## Import ##

# %%
import json
import pandas as pd
import numpy as np
from googleapiclient.discovery import build
from google.oauth2 import service_account

# %% [markdown]
# ## load configuration ##

# %%
environment = 'prod'
try:
    with open("env") as f:
        environment = f.read()
finally:
    pass
    
environment
# Out:
# 'test'

# %%
if environment == 'test':
    config_file = "configuration-test.json"
else:
    config_file = "configuration.json"

with open(config_file) as f:
    config = json.load(f)

config_file
# Out:
# 'configuration-test.json'

# %% [markdown]
# ## Connect to google drive ##

# %%
service_account_file = config["google_account_auth"]
credentials = service_account.Credentials.from_service_account_file(
    service_account_file,
    scopes=['https://www.googleapis.com/auth/spreadsheets.readonly']
)

sheets_service = build('sheets', 'v4', credentials=credentials)

# %% [markdown]
# ## access master data file ##

# %%
spreadsheet_id = config['md_spreadsheet_id']
targets =[
    { 'sheet_name': 'MD_CUSTOMERS', 'columns': 8, 'filename': './data/customers.pkl' },
    { 'sheet_name': 'MD_PLANTS', 'columns': 8, 'filename': './data/plants.pkl' },
    { 'sheet_name': 'MD_MEMBERS', 'columns': 3, 'filename': './data/members.pkl' },
    { 'sheet_name': 'MD_BRANCHES', 'columns': 5, 'filename': './data/branches.pkl' },
    { 'sheet_name': 'MD_SUPPLIERS', 'columns': 2, 'filename': './data/suppliers.pkl' },
    { 'sheet_name': 'MD_PRODUCTFAMILIES', 'columns': 3, 'filename': './data/productfamilies.pkl' },
    { 'sheet_name': 'MD_MONTHS', 'columns': 3, 'filename': './data/months.pkl' },
]

# %%
for target in targets:
    result = sheets_service.spreadsheets().values().get(
        spreadsheetId=spreadsheet_id, range=target['sheet_name']).execute()
    values = result.get('values', [])

    if not values:
        print(target['sheet_name'] + ': No data found.')
    else:
        columns = values[0][:target['columns']]
        data = [
            row + [None] * (target['columns'] - len(row))
            for row in values[1:]
        ]

        data_df = pd.DataFrame(data, columns=columns)

        data_df.head()
        data_df.info()

        data_df.to_pickle(target['filename'])

        print(target['sheet_name'] + ': saved data to file ' + target['filename'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138 entries, 0 to 137
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CUSTOMER_ID           138 non-null    object
#  1   CUSTOMER_NAME         138 non-null    object
#  2   CUSTOMER_INTERNAL_ID  138 non-null    object
#  3   CUSTOMER_FOLDER_NAME  138 non-null    object
#  4   PILOT                 105 non-null    object
#  5   IS_ACTIVE             19 non-null     object
#  6   HAS_CONTRACT          18 non-null     object
#  7   HAS_RFQ               5 non-null      object
# dtypes: object(8)
# memory usage: 8.8+ KB
# MD_CUSTOMERS: saved data to file ./data/customers.pkl
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 818 entries, 0 to 817
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CUSTOMER_ID           818 non-null    object
#  1   PLANT_ID              818 non-null    object
#  2   PLANT_NAME            818 non-null    object
#  3   COUNTRY               818 non-null    object
#  4   CITY                  818 non-null    object
#  5   SECTOR                818 non-null    object
#  6   CUSTOMER_INTERNAL_ID  818 non-null    object
#  7   PLANT_CLOSED          0 non-null      object
# dtypes: object(8)
# memory usage: 51.3+ KB
# MD_PLANTS: saved data to file ./data/plants.pkl
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MEMBER_ID    32 non-null     object
#  1   MEMBER_NAME  32 non-null     object
#  2   COUNTRY      32 non-null     object
# dtypes: object(3)
# memory usage: 900.0+ bytes
# MD_MEMBERS: saved data to file ./data/members.pkl
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MEMBER_ID      195 non-null    object
#  1   BRANCH_ID      195 non-null    object
#  2   BRANCH_NAME    195 non-null    object
#  3   MEMBER_NAME    195 non-null    object
#  4   BRANCH_CLOSED  0 non-null      object
# dtypes: object(5)
# memory usage: 7.7+ KB
# MD_BRANCHES: saved data to file ./data/branches.pkl
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 711 entries, 0 to 710
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SUPPLIER_ID    711 non-null    object
#  1   SUPPLIER_NAME  711 non-null    object
# dtypes: object(2)
# memory usage: 11.2+ KB
# MD_SUPPLIERS: saved data to file ./data/suppliers.pkl
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   PRODUCTFAMILY_ID    19 non-null     object
#  1   PRODUCTFAMILY_CODE  19 non-null     object
#  2   PRODUCTFAMILY_NAME  18 non-null     object
# dtypes: object(3)
# memory usage: 588.0+ bytes
# MD_PRODUCTFAMILIES: saved data to file ./data/productfamilies.pkl
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MONTH_ID    12 non-null     object
#  1   MONTH_CODE  12 non-null     object
#  2   MONTH_NAME  12 non-null     object
# dtypes: object(3)
# memory usage: 420.0+ bytes
# MD_MONTHS: saved data to file ./data/months.pkl
