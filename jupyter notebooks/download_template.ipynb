# %% [markdown]
# ## Import ##

# %%
import json
from googleapiclient.discovery import build
from googleapiclient.http import MediaIoBaseDownload
from google.oauth2 import service_account
import io

# %% [markdown]
# ## load configuration ##

# %%
environment = 'prod'
try:
    with open("env") as f:
        environment = f.read()
finally:
    pass
    
environment
# Out:
# 'test'

# %%
if environment == 'test':
    config_file = "configuration-test.json"
else:
    config_file = "configuration.json"

with open(config_file) as f:
    config = json.load(f)

config_file
# Out:
# 'configuration-test.json'

# %% [markdown]
# ## Connect to google drive ##

# %%
service_account_file = config["google_account_auth"]
credentials = service_account.Credentials.from_service_account_file(
    service_account_file,
    scopes=['https://www.googleapis.com/auth/spreadsheets.readonly']
)

drive_service = build('drive', 'v3', credentials=credentials)

# %% [markdown]
# ## download template ##

# %%
spreadsheet_id = config['template_spreadsheet_id']

request = drive_service.files().export_media(
    fileId=spreadsheet_id,
    mimeType='application/vnd.openxmlformats-officedocument.spreadsheetml.sheet'
)

fh = io.FileIO('output.xlsx', 'wb')
downloader = MediaIoBaseDownload(fh, request)

done = False
while not done:
    status, done = downloader.next_chunk()

print(f"Download finished.")
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# Cell In[5], line 13
#      11 done = False
#      12 while not done:
# ---> 13     status, done = downloader.next_chunk()
#      15 print(f"Download finished.")
#
# File ~/venvs/env_one/lib/python3.12/site-packages/googleapiclient/_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     128     elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File ~/venvs/env_one/lib/python3.12/site-packages/googleapiclient/http.py:780, in MediaIoBaseDownload.next_chunk(self, num_retries)
#     775         self._done = True
#     776         return (
#     777             MediaDownloadProgress(self._progress, self._total_size),
#     778             self._done,
#     779         )
# --> 780 raise HttpError(resp, content, uri=self._uri)
#
# HttpError: <HttpError 403 when requesting https://www.googleapis.com/drive/v3/files/1EFb99RhTT0H6mtxKoP8Jn0hvCqhUJb4k/export?mimeType=application%2Fvnd.openxmlformats-officedocument.spreadsheetml.sheet&alt=media returned "Request had insufficient authentication scopes.". Details: "[{'message': 'Insufficient Permission', 'domain': 'global', 'reason': 'insufficientPermissions'}]">
